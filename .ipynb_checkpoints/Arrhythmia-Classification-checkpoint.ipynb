# %%
import pandas as pd
import numpy as np
import wfdb
import os
from tqdm import tqdm

# %%
wd = os.getcwd()

patient_files = [file for file in os.listdir("ptb-diagnostic-ecg-database-1.0.0/") if 'patient' in file]

data_files = []
for participant in tqdm(patient_files):
    path = wd + "\\ptb-diagnostic-ecg-database-1.0.0\\" + participant
    filename = [i for i in os.listdir(path) if ".dat" in i][0]
    file = path + "\\" + filename

    data = pd.DataFrame()
    for i in range(15):
        signal_name = wfdb.rdsamp(record_name=file[:-4])[1]['sig_name'][i]
        signal = wfdb.rdsamp(record_name=file[:-4])[0][:, i]
        channel = pd.DataFrame({str(signal_name):signal })
        data = pd.concat([data, channel], axis=1)

    data["Participant"] = participant
    data["Label"] = wfdb.rdsamp(file[:-4])[1]['comments'][4].split(':')[-1]
    
    data_files.append(data)

df = pd.concat(data_files)
# Out:
# 100%|██████████| 290/290 [04:26<00:00,  1.09it/s]

# %%
df.to_csv('data.csv',index=False)

# %%
df=pd.read_csv('data.csv')
df.head()
# Out:
#         i      ii     iii     avr     avl     avf      v1      v2      v3  \
# 0 -0.2445 -0.2290  0.0155  0.2370 -0.1300 -0.1070 -0.0440 -0.1205 -0.0560
# 1 -0.2425 -0.2335  0.0090  0.2380 -0.1255 -0.1125 -0.0420 -0.1175 -0.0510
# 2 -0.2415 -0.2345  0.0070  0.2380 -0.1240 -0.1140 -0.0440 -0.1180 -0.0535
# 3 -0.2410 -0.2290  0.0120  0.2350 -0.1260 -0.1090 -0.0450 -0.1175 -0.0515
# 4 -0.2315 -0.2270  0.0045  0.2295 -0.1180 -0.1115 -0.0455 -0.1170 -0.0495
#
#        v4      v5      v6      vx      vy      vz Participant  \
# 0  0.1060  0.1965  0.1950 -0.0015  0.0600 -0.0090  patient001
# 1  0.1095  0.2020  0.1980 -0.0015  0.0610 -0.0100  patient001
# 2  0.1095  0.2005  0.1965 -0.0035  0.0555 -0.0085  patient001
# 3  0.1115  0.2010  0.1970 -0.0020  0.0535 -0.0080  patient001
# 4  0.1115  0.2000  0.1985  0.0005  0.0545 -0.0085  patient001
#
#                     Label
# 0   Myocardial infarction
# 1   Myocardial infarction
# 2   Myocardial infarction
# 3   Myocardial infarction
# 4   Myocardial infarction

# %%
from sklearn.preprocessing import LabelEncoder
df[['Label']] = df[['Label']].apply(LabelEncoder().fit_transform)

# %%
from sklearn.preprocessing import LabelEncoder

# Apply label encoding
df[['Label']] = df[['Label']].apply(LabelEncoder().fit_transform)

# Get unique classes and their encoded labels
unique_labels = df['Label'].unique()

# Print the classes and corresponding labels
for label in unique_labels:
    class_name = df[df['Label'] == label]['Label'].iloc[0]  # Get the class name corresponding to the label
    print(f"Class: {class_name}, Encoded Label: {label}")
# Out:
# Class: 8, Encoded Label: 8
# Class: 3, Encoded Label: 3
# Class: 13, Encoded Label: 13
# Class: 2, Encoded Label: 2
# Class: 4, Encoded Label: 4
# Class: 5, Encoded Label: 5
# Class: 14, Encoded Label: 14
# Class: 6, Encoded Label: 6
# Class: 10, Encoded Label: 10
# Class: 1, Encoded Label: 1
# Class: 11, Encoded Label: 11
# Class: 7, Encoded Label: 7
# Class: 0, Encoded Label: 0
# Class: 12, Encoded Label: 12
# Class: 9, Encoded Label: 9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30185011 entries, 0 to 30185010
# Data columns (total 17 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   i            float64
#  1   ii           float64
#  2   iii          float64
#  3   avr          float64
#  4   avl          float64
#  5   avf          float64
#  6   v1           float64
#  7   v2           float64
#  8   v3           float64
#  9   v4           float64
#  10  v5           float64
#  11  v6           float64
#  12  vx           float64
#  13  vy           float64
#  14  vz           float64
#  15  Participant  object
#  16  Label        int32
# dtypes: float64(15), int32(1), object(1)
# memory usage: 3.7+ GB

# %%
df['Label'].value_counts()
# Out:
# Label
# 8     16001824
# 3      6109920
# 0      1680919
# 1      1627332
# 14     1555248
# 2      1166436
# 7       835272
# 9       480048
# 13      382412
# 11      153600
# 4        38400
# 5        38400
# 6        38400
# 10       38400
# 12       38400
# Name: count, dtype: int64

# %%
df_0=(df[df['Label']==8]).sample(n=5000,random_state=42)
df_1=(df[df['Label']==3]).sample(n=5000,random_state=42)
df_2=(df[df['Label']==0]).sample(n=5000,random_state=42)
df_3=(df[df['Label']==1]).sample(n=5000,random_state=42)
df_4=(df[df['Label']==2]).sample(n=5000,random_state=42)
df_5=(df[df['Label']==7]).sample(n=5000,random_state=42)
df_6=(df[df['Label']==9]).sample(n=5000,random_state=42)
df_7=(df[df['Label']==13]).sample(n=5000,random_state=42)
df_8=(df[df['Label']==11]).sample(n=5000,random_state=42)
df_9=(df[df['Label']==4]).sample(n=5000,random_state=42)
df_10=(df[df['Label']==5]).sample(n=5000,random_state=42)
df_11=(df[df['Label']==6]).sample(n=5000,random_state=42)
df_12=(df[df['Label']==10]).sample(n=5000,random_state=42)
df_13=(df[df['Label']==12]).sample(n=5000,random_state=42)

# %%
new_df=pd.concat([df_0,df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9,df_10,df_11,df_12,df_13])

# %%
new_df['Label'].value_counts()
# Out:
# Label
# 8     5000
# 3     5000
# 0     5000
# 1     5000
# 2     5000
# 7     5000
# 9     5000
# 13    5000
# 11    5000
# 4     5000
# 5     5000
# 6     5000
# 10    5000
# 12    5000
# Name: count, dtype: int64

# %%
new_df=new_df.reset_index(drop=True)

# %%
new_df.drop(['Participant'],axis=1,inplace=True)

# %%
new_df
# Out:
#             i      ii     iii     avr     avl     avf      v1      v2      v3  \
# 0      0.2840  0.5480  0.2640 -0.4160  0.0100  0.4060  0.2865  0.0865  0.1605
# 1      0.0525 -0.0135 -0.0665 -0.0200  0.0595 -0.0400  0.1485  0.0550  0.1070
# 2     -2.0630 -1.8775  0.1855  1.9705 -1.1240 -0.8460  0.4335 -1.2030 -1.3150
# 3      0.0105 -0.0665 -0.0765  0.0275  0.0440 -0.0710  0.0980 -0.0020  0.0465
# 4     -0.1375  0.2790  0.4175 -0.0710 -0.2770  0.3480 -0.1715 -0.3300 -0.4625
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 69995  0.1240 -0.3270 -0.4505  0.1015  0.2875 -0.3885 -0.6390 -0.6305 -0.7955
# 69996 -0.0815 -0.0685  0.0130  0.0750 -0.0470 -0.0275  0.0770  0.0595  0.0775
# 69997 -0.1485  0.2430  0.3915 -0.0470 -0.2700  0.3175  0.5015  0.5115  0.5190
# 69998 -0.2850 -0.0130  0.2720  0.1495 -0.2785  0.1295  0.5695  0.3720  0.2405
# 69999  0.1030 -0.3415 -0.4445  0.1195  0.2735 -0.3925 -0.6765 -0.6605 -0.8155
#
#            v4      v5      v6      vx      vy      vz  Label
# 0      0.2010  0.0370  0.0445 -0.0510  0.1555 -0.0915      8
# 1      0.1005  0.2035 -0.2625 -0.1415 -0.1785 -0.2200      8
# 2     -0.9390 -1.1360 -0.5235 -0.0515 -2.9295 -1.6390      8
# 3      0.0330 -0.2745 -0.0800 -0.1460 -0.1405  0.0150      8
# 4     -0.3505 -0.2835 -0.2020 -0.0350  0.2940  0.1220      8
# ...       ...     ...     ...     ...     ...     ...    ...
# 69995 -0.8495 -0.8210 -0.8085 -0.0015 -0.0545  0.5695     12
# 69996  0.0125 -0.1005 -0.0960 -0.0850 -0.1050 -0.0560     12
# 69997  0.5000  0.4410  0.4215 -0.0900  0.0525 -0.4870     12
# 69998  0.0035 -0.2095 -0.2175 -0.3740 -0.0505 -0.3970     12
# 69999 -0.8685 -0.8615 -0.8500 -0.0120 -0.0515  0.5830     12
#
# [70000 rows x 16 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.metrics import accuracy_score

# %%
X = new_df.drop('Label', axis=1)
y = new_df['Label']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=21)

# %%
X_train=np.array(X_train)
X_test=np.array(X_test)

# %%
X_train = X_train.reshape(len(X_train), X_train.shape[1],1)
X_test = X_test.reshape(len(X_test), X_test.shape[1],1)

# %%
X_test.shape
# Out:
# (21000, 15, 1)

# %%
import tensorflow.keras
y_train=tensorflow.keras.utils.to_categorical(y_train)
y_test=tensorflow.keras.utils.to_categorical(y_test)
# Out:
# WARNING:tensorflow:From C:\Users\annit\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def network(X_train,y_train,X_test,y_test):
    

    im_shape=(X_train.shape[1],1)
    inputs_cnn=Input(shape=(im_shape), name='inputs_cnn')
    conv1_1=Convolution1D(32, (3), activation='relu', input_shape=im_shape)(inputs_cnn)
    conv1_1=BatchNormalization()(conv1_1)
    pool1=MaxPool1D(pool_size=(3), strides=(2), padding="same")(conv1_1)
    conv2_1=Convolution1D(64, (3), activation='relu', input_shape=im_shape)(pool1)
    conv2_1=BatchNormalization()(conv2_1)
    pool2=MaxPool1D(pool_size=(2), strides=(2), padding="same")(conv2_1)
    conv3_1=Convolution1D(128, (3), activation='relu', input_shape=im_shape)(pool2)
    conv3_1=BatchNormalization()(conv3_1)
    pool3=MaxPool1D(pool_size=(2), strides=(2), padding="same")(conv3_1)
    flatten=Flatten()(pool3)
    dense_end1 = Dense(128, activation='relu')(flatten)
    dense_end2 = Dense(32, activation='relu')(dense_end1)
    main_output = Dense(14, activation='softmax', name='main_output')(dense_end2)
    
    
    model = Model(inputs= inputs_cnn, outputs=main_output)
    opt=tensorflow.keras.optimizers.Adam(lr=0.001)
    model.compile(optimizer=opt, loss='categorical_crossentropy',metrics = ['accuracy'])
    checkpoint = ModelCheckpoint('best_model.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    early = EarlyStopping(monitor="val_accuracy", mode="max", patience=5, verbose=1)
    redonplat = ReduceLROnPlateau(monitor="val_accuracy", mode="max", patience=3, verbose=2)
    callbacks= [checkpoint, early, redonplat]  # early

    history=model.fit(X_train, y_train,epochs=50,callbacks=callbacks, batch_size=16,validation_data=(X_test,y_test))
    return(model,history)

# %%
from keras.layers import Dense, Convolution1D, MaxPool1D, Flatten, Dropout
from keras.layers import Input
from keras.models import Model
from keras.layers import BatchNormalization
import keras
from keras.callbacks import EarlyStopping, ModelCheckpoint,ReduceLROnPlateau
model,history=network(X_train,y_train,X_test,y_test)
# Out:
# WARNING:tensorflow:From C:\Users\annit\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\annit\anaconda3\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\annit\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From C:\Users\annit\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From C:\Users\annit\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From C:\Users\annit\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# 3063/3063 [==============================] - ETA: 0s - loss: 1.2417 - accuracy: 0.6066
# Epoch 1: val_accuracy improved from -inf to 0.73257, saving model to best_model.h5
# 3063/3063 [==============================] - 43s 12ms/step - loss: 1.2417 - accuracy: 0.6066 - val_loss: 0.8501 - val_accuracy: 0.7326 - lr: 0.0010
# Epoch 2/50
#    1/3063 [..............................] - ETA: 27s - loss: 0.6521 - accuracy: 0.6875
# C:\Users\annit\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 3060/3063 [============================>.] - ETA: 0s - loss: 0.7999 - accuracy: 0.7413
# Epoch 2: val_accuracy improved from 0.73257 to 0.78386, saving model to best_model.h5
# 3063/3063 [==============================] - 36s 12ms/step - loss: 0.8000 - accuracy: 0.7412 - val_loss: 0.6723 - val_accuracy: 0.7839 - lr: 0.0010
# Epoch 3/50
# 3061/3063 [============================>.] - ETA: 0s - loss: 0.6668 - accuracy: 0.7857
# Epoch 3: val_accuracy improved from 0.78386 to 0.81229, saving model to best_model.h5
# 3063/3063 [==============================] - 36s 12ms/step - loss: 0.6668 - accuracy: 0.7857 - val_loss: 0.5776 - val_accuracy: 0.8123 - lr: 0.0010
# Epoch 4/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.5901 - accuracy: 0.8089
# Epoch 4: val_accuracy improved from 0.81229 to 0.84610, saving model to best_model.h5
# 3063/3063 [==============================] - 36s 12ms/step - loss: 0.5900 - accuracy: 0.8089 - val_loss: 0.4725 - val_accuracy: 0.8461 - lr: 0.0010
# Epoch 5/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.5374 - accuracy: 0.8234
# Epoch 5: val_accuracy improved from 0.84610 to 0.85595, saving model to best_model.h5
# 3063/3063 [==============================] - 37s 12ms/step - loss: 0.5375 - accuracy: 0.8233 - val_loss: 0.4523 - val_accuracy: 0.8560 - lr: 0.0010
# Epoch 6/50
# 3061/3063 [============================>.] - ETA: 0s - loss: 0.5049 - accuracy: 0.8331
# Epoch 6: val_accuracy improved from 0.85595 to 0.86943, saving model to best_model.h5
# 3063/3063 [==============================] - 31s 10ms/step - loss: 0.5049 - accuracy: 0.8331 - val_loss: 0.4072 - val_accuracy: 0.8694 - lr: 0.0010
# Epoch 7/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.4677 - accuracy: 0.8473
# Epoch 7: val_accuracy improved from 0.86943 to 0.87148, saving model to best_model.h5
# 3063/3063 [==============================] - 29s 9ms/step - loss: 0.4676 - accuracy: 0.8474 - val_loss: 0.3975 - val_accuracy: 0.8715 - lr: 0.0010
# Epoch 8/50
# 3061/3063 [============================>.] - ETA: 0s - loss: 0.4398 - accuracy: 0.8565
# Epoch 8: val_accuracy improved from 0.87148 to 0.88129, saving model to best_model.h5
# 3063/3063 [==============================] - 29s 9ms/step - loss: 0.4398 - accuracy: 0.8565 - val_loss: 0.3652 - val_accuracy: 0.8813 - lr: 0.0010
# Epoch 9/50
# 3057/3063 [============================>.] - ETA: 0s - loss: 0.4177 - accuracy: 0.8626
# Epoch 9: val_accuracy did not improve from 0.88129
# 3063/3063 [==============================] - 27s 9ms/step - loss: 0.4177 - accuracy: 0.8626 - val_loss: 0.3805 - val_accuracy: 0.8799 - lr: 0.0010
# Epoch 10/50
# 3060/3063 [============================>.] - ETA: 0s - loss: 0
saving model to best_model.h5
# 3063/3063 [==============================] - 30s 10ms/step - loss: 0.1454 - accuracy: 0.9523 - val_loss: 0.2114 - val_accuracy: 0.9380 - lr: 1.0000e-04
# Epoch 37/50
# 3059/3063 [============================>.] - ETA: 0s - loss: 0.1423 - accuracy: 0.9523
# Epoch 37: val_accuracy did not improve from 0.93795
# 3063/3063 [==============================] - 30s 10ms/step - loss: 0.1422 - accuracy: 0.9523 - val_loss: 0.2134 - val_accuracy: 0.9379 - lr: 1.0000e-04
# Epoch 38/50
# 3060/3063 [============================>.] - ETA: 0s - loss: 0.1455 - accuracy: 0.9508
# Epoch 38: val_accuracy improved from 0.93795 to 0.94038, saving model to best_model.h5
# 3063/3063 [==============================] - 30s 10ms/step - loss: 0.1455 - accuracy: 0.9508 - val_loss: 0.2084 - val_accuracy: 0.9404 - lr: 1.0000e-04
# Epoch 39/50
# 3058/3063 [============================>.] - ETA: 0s - loss: 0.1413 - accuracy: 0.9524
# Epoch 39: val_accuracy did not improve from 0.94038
# 3063/3063 [==============================] - 28s 9ms/step - loss: 0.1414 - accuracy: 0.9523 - val_loss: 0.2127 - val_accuracy: 0.9393 - lr: 1.0000e-04
# Epoch 40/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.1421 - accuracy: 0.9516
# Epoch 40: val_accuracy did not improve from 0.94038
# 3063/3063 [==============================] - 29s 9ms/step - loss: 0.1421 - accuracy: 0.9516 - val_loss: 0.2103 - val_accuracy: 0.9397 - lr: 1.0000e-04
# Epoch 41/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.1372 - accuracy: 0.9537
# Epoch 41: val_accuracy did not improve from 0.94038
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 3063/3063 [==============================] - 29s 10ms/step - loss: 0.1372 - accuracy: 0.9538 - val_loss: 0.2127 - val_accuracy: 0.9391 - lr: 1.0000e-04
# Epoch 42/50
# 3061/3063 [============================>.] - ETA: 0s - loss: 0.1332 - accuracy: 0.9556
# Epoch 42: val_accuracy improved from 0.94038 to 0.94052, saving model to best_model.h5
# 3063/3063 [==============================] - 30s 10ms/step - loss: 0.1332 - accuracy: 0.9556 - val_loss: 0.2090 - val_accuracy: 0.9405 - lr: 1.0000e-05
# Epoch 43/50
# 3056/3063 [============================>.] - ETA: 0s - loss: 0.1341 - accuracy: 0.9554
# Epoch 43: val_accuracy improved from 0.94052 to 0.94152, saving model to best_model.h5
# 3063/3063 [==============================] - 29s 10ms/step - loss: 0.1340 - accuracy: 0.9553 - val_loss: 0.2068 - val_accuracy: 0.9415 - lr: 1.0000e-05
# Epoch 44/50
# 3058/3063 [============================>.] - ETA: 0s - loss: 0.1305 - accuracy: 0.9551
# Epoch 44: val_accuracy did not improve from 0.94152
# 3063/3063 [==============================] - 30s 10ms/step - loss: 0.1305 - accuracy: 0.9552 - val_loss: 0.2081 - val_accuracy: 0.9400 - lr: 1.0000e-05
# Epoch 45/50
# 3063/3063 [==============================] - ETA: 0s - loss: 0.1326 - accuracy: 0.9553
# Epoch 45: val_accuracy did not improve from 0.94152
# 3063/3063 [==============================] - 30s 10ms/step - loss: 0.1326 - accuracy: 0.9553 - val_loss: 0.2062 - val_accuracy: 0.9406 - lr: 1.0000e-05
# Epoch 46/50
# 3059/3063 [============================>.] - ETA: 0s - loss: 0.1321 - accuracy: 0.9555
# Epoch 46: val_accuracy did not improve from 0.94152
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 3063/3063 [==============================] - 30s 10ms/step - loss: 0.1321 - accuracy: 0.9556 - val_loss: 0.2063 - val_accuracy: 0.9409 - lr: 1.0000e-05
# Epoch 47/50
# 3060/3063 [============================>.] - ETA: 0s - loss: 0.1275 - accuracy: 0.9572
# Epoch 47: val_accuracy did not improve from 0.94152
# 3063/3063 [==============================] - 28s 9ms/step - loss: 0.1275 - accuracy: 0.9572 - val_loss: 0.2066 - val_accuracy: 0.9391 - lr: 1.0000e-06
# Epoch 48/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.1272 - accuracy: 0.9567
# Epoch 48: val_accuracy did not improve from 0.94152
# 3063/3063 [==============================] - 29s 9ms/step - loss: 0.1273 - accuracy: 0.9566 - val_loss: 0.2065 - val_accuracy: 0.9407 - lr: 1.0000e-06
# Epoch 48: early stopping

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Model - Accuracy')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()
    
plt.legend(['Training', 'Validation'], loc='upper right')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Model- Loss')
plt.show()

# %%
from sklearn.metrics import confusion_matrix,classification_report
import seaborn as sns

# %%
prediction_proba=model.predict(X_test)
prediction=np.argmax(prediction_proba,axis=1)
# Out:
# 657/657 [==============================] - 4s 5ms/step

# %%
conf_matrix = confusion_matrix(np.argmax(y_test,axis=1), prediction)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Reds")
# Out:
# <Axes: >

# %%
print(classification_report(np.argmax(y_test,axis=1), prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.90      1533
#            1       0.94      0.93      0.94      1494
#            2       0.89      0.92      0.91      1488
#            3       0.85      0.83      0.84      1531
#            4       0.98      1.00      0.99      1531
#            5       0.99      1.00      1.00      1497
#            6       0.98      0.99      0.98      1535
#            7       0.93      0.95      0.94      1460
#            8       0.85      0.69      0.76      1511
#            9       0.98      0.99      0.98      1464
#           10       0.96      1.00      0.98      1531
#           11       0.97      0.99      0.98      1487
#           12       0.98      1.00      0.99      1482
#           13       0.96      0.96      0.96      1456
#
#     accuracy                           0.94     21000
#    macro avg       0.94      0.94      0.94     21000
# weighted avg       0.94      0.94      0.94     21000

# %%
for layer in model.layers:
    print(layer.name)
# Out:
# inputs_cnn
# conv1d
# batch_normalization
# max_pooling1d
# conv1d_1
# batch_normalization_1
# max_pooling1d_1
# conv1d_2
# batch_normalization_2
# max_pooling1d_2
# flatten
# dense
# dense_1
# main_output

# %%
dense_11_layer_model = Model(inputs=model.input,
                                 outputs=model.get_layer('dense_1').output)

# %%
feature = dense_11_layer_model.predict(X_train)
# Out:
# 1532/1532 [==============================] - 7s 4ms/step

# %%
feature.shape
# Out:
# (49000, 32)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators = 100, random_state = 42)

rf.fit(feature, np.argmax(y_train,axis=1))
# Out:
# RandomForestClassifier(random_state=42)

# %%
test_data=dense_11_layer_model.predict(X_test)
# Out:
# 657/657 [==============================] - 3s 4ms/step

# %%
test_data.shape
# Out:
# (21000, 32)

# %%
predictions = rf.predict(test_data)

# %%
accuracy=accuracy_score(predictions , np.argmax(y_test,axis=1))
print('Accuracy:', accuracy*100, '%.')
# Out:
# Accuracy: 94.18095238095238 %.

# %%
conf_matrix = confusion_matrix(np.argmax(y_test,axis=1), predictions)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Reds")
# Out:
# <Axes: >

# %%
print(classification_report(np.argmax(y_test,axis=1), prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.90      1533
#            1       0.94      0.93      0.94      1494
#            2       0.89      0.92      0.91      1488
#            3       0.85      0.83      0.84      1531
#            4       0.98      1.00      0.99      1531
#            5       0.99      1.00      1.00      1497
#            6       0.98      0.99      0.98      1535
#            7       0.93      0.95      0.94      1460
#            8       0.85      0.69      0.76      1511
#            9       0.98      0.99      0.98      1464
#           10       0.96      1.00      0.98      1531
#           11       0.97      0.99      0.98      1487
#           12       0.98      1.00      0.99      1482
#           13       0.96      0.96      0.96      1456
#
#     accuracy                           0.94     21000
#    macro avg       0.94      0.94      0.94     21000
# weighted avg       0.94      0.94      0.94     21000

# %%
def buildModel():
    newModel = tensorflow.keras.models.Sequential([
        tensorflow.keras.layers.InputLayer(input_shape=(X_train.shape[1], 1)),
        tensorflow.keras.layers.Conv1D(filters=16, kernel_size=21, strides=1, padding='SAME', activation='relu'),
        tensorflow.keras.layers.MaxPool1D(pool_size=3, strides=2, padding='SAME'),
        tensorflow.keras.layers.Conv1D(filters=32, kernel_size=23, strides=1, padding='SAME', activation='relu'),
        tensorflow.keras.layers.MaxPool1D(pool_size=3, strides=2, padding='SAME'),
        tensorflow.keras.layers.Conv1D(filters=64, kernel_size=25, strides=1, padding='SAME', activation='relu'),
        tensorflow.keras.layers.AvgPool1D(pool_size=3, strides=2, padding='SAME'),
        tensorflow.keras.layers.Conv1D(filters=128, kernel_size=27, strides=1, padding='SAME', activation='relu'),
        tensorflow.keras.layers.LSTM(128, return_sequences=True),
        tensorflow.keras.layers.Dropout(rate=0.2),
        tensorflow.keras.layers.LSTM(64, return_sequences=True),
        tensorflow.keras.layers.Flatten(),
        tensorflow.keras.layers.Dense(128, activation='relu'),
        tensorflow.keras.layers.Dropout(rate=0.2),
        tensorflow.keras.layers.Dense(14, activation='softmax')
    ])
    return newModel

# %%
model = buildModel()
opt=tensorflow.keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=opt, loss='categorical_crossentropy',metrics = ['accuracy'])
checkpoint = ModelCheckpoint('best_model_1.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early = EarlyStopping(monitor="val_accuracy", mode="max", patience=5, verbose=1)
redonplat = ReduceLROnPlateau(monitor="val_accuracy", mode="max", patience=3, verbose=2)
callbacks= [checkpoint, early, redonplat]  # early

history=model.fit(X_train, y_train,epochs=50,callbacks=callbacks, batch_size=16,validation_data=(X_test,y_test))
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/50
# 3063/3063 [==============================] - ETA: 0s - loss: 1.8147 - accuracy: 0.3689
# Epoch 1: val_accuracy improved from -inf to 0.55319, saving model to best_model_1.h5
# 3063/3063 [==============================] - 73s 21ms/step - loss: 1.8147 - accuracy: 0.3689 - val_loss: 1.3449 - val_accuracy: 0.5532 - lr: 0.0010
# Epoch 2/50
#    4/3063 [..............................] - ETA: 53s - loss: 1.4114 - accuracy: 0.4531
# C:\Users\annit\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 3063/3063 [==============================] - ETA: 0s - loss: 1.1517 - accuracy: 0.6123
# Epoch 2: val_accuracy improved from 0.55319 to 0.64957, saving model to best_model_1.h5
# 3063/3063 [==============================] - 62s 20ms/step - loss: 1.1517 - accuracy: 0.6123 - val_loss: 1.0458 - val_accuracy: 0.6496 - lr: 0.0010
# Epoch 3/50
# 3061/3063 [============================>.] - ETA: 0s - loss: 0.9490 - accuracy: 0.6847
# Epoch 3: val_accuracy improved from 0.64957 to 0.70881, saving model to best_model_1.h5
# 3063/3063 [==============================] - 61s 20ms/step - loss: 0.9488 - accuracy: 0.6848 - val_loss: 0.8582 - val_accuracy: 0.7088 - lr: 0.0010
# Epoch 4/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.8178 - accuracy: 0.7257
# Epoch 4: val_accuracy improved from 0.70881 to 0.74005, saving model to best_model_1.h5
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.8178 - accuracy: 0.7257 - val_loss: 0.7989 - val_accuracy: 0.7400 - lr: 0.0010
# Epoch 5/50
# 3061/3063 [============================>.] - ETA: 0s - loss: 0.7154 - accuracy: 0.7616
# Epoch 5: val_accuracy improved from 0.74005 to 0.77805, saving model to best_model_1.h5
# 3063/3063 [==============================] - 63s 20ms/step - loss: 0.7153 - accuracy: 0.7617 - val_loss: 0.6908 - val_accuracy: 0.7780 - lr: 0.0010
# Epoch 6/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.6346 - accuracy: 0.7892
# Epoch 6: val_accuracy improved from 0.77805 to 0.80310, saving model to best_model_1.h5
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.6345 - accuracy: 0.7892 - val_loss: 0.5880 - val_accuracy: 0.8031 - lr: 0.0010
# Epoch 7/50
# 3061/3063 [============================>.] - ETA: 0s - loss: 0.5745 - accuracy: 0.8087
# Epoch 7: val_accuracy improved from 0.80310 to 0.81871, saving model to best_model_1.h5
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.5746 - accuracy: 0.8087 - val_loss: 0.5393 - val_accuracy: 0.8187 - lr: 0.0010
# Epoch 8/50
# 3061/3063 [============================>.] - ETA: 0s - loss: 0.5226 - accuracy: 0.8255
# Epoch 8: val_accuracy improved from 0.81871 to 0.82605, saving model to best_model_1.h5
# 3063/3063 [==============================] - 60s 20ms/step - loss: 0.5224 - accuracy: 0.8256 - val_loss: 0.5304 - val_accuracy: 0.8260 - lr: 0.0010
# Epoch
50
# 3063/3063 [==============================] - ETA: 0s - loss: 0.2168 - accuracy: 0.9294
# Epoch 25: val_accuracy did not improve from 0.91024
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.2168 - accuracy: 0.9294 - val_loss: 0.3287 - val_accuracy: 0.9034 - lr: 0.0010
# Epoch 26/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.2061 - accuracy: 0.9329
# Epoch 26: val_accuracy improved from 0.91024 to 0.91157, saving model to best_model_1.h5
# 3063/3063 [==============================] - 61s 20ms/step - loss: 0.2061 - accuracy: 0.9329 - val_loss: 0.3078 - val_accuracy: 0.9116 - lr: 0.0010
# Epoch 27/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.1980 - accuracy: 0.9364
# Epoch 27: val_accuracy did not improve from 0.91157
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.1981 - accuracy: 0.9363 - val_loss: 0.3438 - val_accuracy: 0.9013 - lr: 0.0010
# Epoch 28/50
# 3063/3063 [==============================] - ETA: 0s - loss: 0.1914 - accuracy: 0.9367
# Epoch 28: val_accuracy did not improve from 0.91157
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.1914 - accuracy: 0.9367 - val_loss: 0.3239 - val_accuracy: 0.9099 - lr: 0.0010
# Epoch 29/50
# 3063/3063 [==============================] - ETA: 0s - loss: 0.1877 - accuracy: 0.9389
# Epoch 29: val_accuracy improved from 0.91157 to 0.91571, saving model to best_model_1.h5
# 3063/3063 [==============================] - 61s 20ms/step - loss: 0.1877 - accuracy: 0.9389 - val_loss: 0.2937 - val_accuracy: 0.9157 - lr: 0.0010
# Epoch 30/50
# 3061/3063 [============================>.] - ETA: 0s - loss: 0.1826 - accuracy: 0.9411
# Epoch 30: val_accuracy did not improve from 0.91571
# 3063/3063 [==============================] - 61s 20ms/step - loss: 0.1826 - accuracy: 0.9411 - val_loss: 0.3074 - val_accuracy: 0.9120 - lr: 0.0010
# Epoch 31/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.1769 - accuracy: 0.9422
# Epoch 31: val_accuracy did not improve from 0.91571
# 3063/3063 [==============================] - 61s 20ms/step - loss: 0.1768 - accuracy: 0.9422 - val_loss: 0.3059 - val_accuracy: 0.9123 - lr: 0.0010
# Epoch 32/50
# 3063/3063 [==============================] - ETA: 0s - loss: 0.1665 - accuracy: 0.9457
# Epoch 32: val_accuracy improved from 0.91571 to 0.91643, saving model to best_model_1.h5
# 3063/3063 [==============================] - 61s 20ms/step - loss: 0.1665 - accuracy: 0.9457 - val_loss: 0.2944 - val_accuracy: 0.9164 - lr: 0.0010
# Epoch 33/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.1663 - accuracy: 0.9462
# Epoch 33: val_accuracy improved from 0.91643 to 0.91652, saving model to best_model_1.h5
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.1663 - accuracy: 0.9462 - val_loss: 0.3077 - val_accuracy: 0.9165 - lr: 0.0010
# Epoch 34/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.1608 - accuracy: 0.9479
# Epoch 34: val_accuracy did not improve from 0.91652
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.1608 - accuracy: 0.9479 - val_loss: 0.3608 - val_accuracy: 0.9013 - lr: 0.0010
# Epoch 35/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.1564 - accuracy: 0.9486
# Epoch 35: val_accuracy did not improve from 0.91652
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.1564 - accuracy: 0.9487 - val_loss: 0.3025 - val_accuracy: 0.9157 - lr: 0.0010
# Epoch 36/50
# 3061/3063 [============================>.] - ETA: 0s - loss: 0.0881 - accuracy: 0.9708
# Epoch 36: val_accuracy improved from 0.91652 to 0.93067, saving model to best_model_1.h5
# 3063/3063 [==============================] - 61s 20ms/step - loss: 0.0881 - accuracy: 0.9708 - val_loss: 0.2767 - val_accuracy: 0.9307 - lr: 1.0000e-04
# Epoch 37/50
# 3061/3063 [============================>.] - ETA: 0s - loss: 0.0628 - accuracy: 0.9791
# Epoch 37: val_accuracy improved from 0.93067 to 0.93252, saving model to best_model_1.h5
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.0628 - accuracy: 0.9791 - val_loss: 0.2968 - val_accuracy: 0.9325 - lr: 1.0000e-04
# Epoch 38/50
# 3063/3063 [==============================] - ETA: 0s - loss: 0.0536 - accuracy: 0.9821
# Epoch 38: val_accuracy improved from 0.93252 to 0.93333, saving model to best_model_1.h5
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.0536 - accuracy: 0.9821 - val_loss: 0.3063 - val_accuracy: 0.9333 - lr: 1.0000e-04
# Epoch 39/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.0467 - accuracy: 0.9843
# Epoch 39: val_accuracy did not improve from 0.93333
# 3063/3063 [==============================] - 61s 20ms/step - loss: 0.0467 - accuracy: 0.9843 - val_loss: 0.3280 - val_accuracy: 0.9333 - lr: 1.0000e-04
# Epoch 40/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.0408 - accuracy: 0.9862
# Epoch 40: val_accuracy did not improve from 0.93333
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.0408 - accuracy: 0.9862 - val_loss: 0.3512 - val_accuracy: 0.9316 - lr: 1.0000e-04
# Epoch 41/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.0370 - accuracy: 0.9878
# Epoch 41: val_accuracy improved from 0.93333 to 0.93419, saving model to best_model_1.h5
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.0370 - accuracy: 0.9878 - val_loss: 0.3526 - val_accuracy: 0.9342 - lr: 1.0000e-04
# Epoch 42/50
# 3061/3063 [============================>.] - ETA: 0s - loss: 0.0344 - accuracy: 0.9887
# Epoch 42: val_accuracy did not improve from 0.93419
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.0344 - accuracy: 0.9887 - val_loss: 0.3738 - val_accuracy: 0.9335 - lr: 1.0000e-04
# Epoch 43/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.0320 - accuracy: 0.9894
# Epoch 43: val_accuracy did not improve from 0.93419
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.0320 - accuracy: 0.9894 - val_loss: 0.3864 - val_accuracy: 0.9334 - lr: 1.0000e-04
# Epoch 44/50
# 3060/3063 [============================>.] - ETA: 0s - loss: 0.0296 - accuracy: 0.9904
# Epoch 44: val_accuracy did not improve from 0.93419
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.0296 - accuracy: 0.9904 - val_loss: 0.4031 - val_accuracy: 0.9341 - lr: 1.0000e-04
# Epoch 45/50
# 3063/3063 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9925
# Epoch 45: val_accuracy improved from 0.93419 to 0.93476, saving model to best_model_1.h5
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.0236 - accuracy: 0.9925 - val_loss: 0.4025 - val_accuracy: 0.9348 - lr: 1.0000e-05
# Epoch 46/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.0227 - accuracy: 0.9926
# Epoch 46: val_accuracy did not improve from 0.93476
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.0227 - accuracy: 0.9926 - val_loss: 0.4048 - val_accuracy: 0.9343 - lr: 1.0000e-05
# Epoch 47/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.0212 - accuracy: 0.9933
# Epoch 47: val_accuracy did not improve from 0.93476
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.0212 - accuracy: 0.9933 - val_loss: 0.4099 - val_accuracy: 0.9345 - lr: 1.0000e-05
# Epoch 48/50
# 3062/3063 [============================>.] - ETA: 0s - loss: 0.0207 - accuracy: 0.9939
# Epoch 48: val_accuracy improved from 0.93476 to 0.93481, saving model to best_model_1.h5
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.0207 - accuracy: 0.9939 - val_loss: 0.4126 - val_accuracy: 0.9348 - lr: 1.0000e-05
# Epoch 49/50
# 3063/3063 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9932
# Epoch 49: val_accuracy did not improve from 0.93481
# 3063/3063 [==============================] - 62s 20ms/step - loss: 0.0205 - accuracy: 0.9932 - val_loss: 0.4129 - val_accuracy: 0.9347 - lr: 1.0000e-06
# Epoch 50/50
# 3063/3063 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9940
# Epoch 50: val_accuracy did not improve from 0.93481
# 3063/3063 [==============================] - 61s 20ms/step - loss: 0.0198 - accuracy: 0.9940 - val_loss: 0.4132 - val_accuracy: 0.9348 - lr: 1.0000e-06

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Model - Accuracy')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()
    
plt.legend(['Training', 'Validation'], loc='upper right')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Model- Loss')
plt.show()

# %%
prediction_proba=model.predict(X_test)
prediction=np.argmax(prediction_proba,axis=1)
# Out:
# 657/657 [==============================] - 6s 7ms/step

# %%
conf_matrix = confusion_matrix(np.argmax(y_test,axis=1), predictions)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Reds")
# Out:
# <Axes: >

# %%
print(classification_report(np.argmax(y_test,axis=1), prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.89      1533
#            1       0.92      0.93      0.92      1494
#            2       0.91      0.91      0.91      1488
#            3       0.84      0.83      0.84      1531
#            4       0.98      0.99      0.98      1531
#            5       0.99      1.00      1.00      1497
#            6       0.99      0.98      0.98      1535
#            7       0.94      0.94      0.94      1460
#            8       0.75      0.72      0.74      1511
#            9       0.99      0.98      0.98      1464
#           10       0.98      1.00      0.99      1531
#           11       0.97      0.98      0.97      1487
#           12       0.99      1.00      0.99      1482
#           13       0.94      0.95      0.94      1456
#
#     accuracy                           0.93     21000
#    macro avg       0.93      0.94      0.93     21000
# weighted avg       0.93      0.93      0.93     21000

# %%
# Assuming `df` is your concatenated DataFrame containing both train and test data
# You can split it into train and test portions as per your previous code
# For demonstration, I'll use train_test_split to create a test set from your data

from sklearn.model_selection import train_test_split

# Splitting the data into train and test sets
train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)

# Save the test data to a CSV file
test_data.to_csv('test_data.csv', index=False)

# %%
test_data.to_csv('test_data.csv', index=False)
